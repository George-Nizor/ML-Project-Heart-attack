# %%
import pandas as pd

# %%
df = pd.read_csv('heart_attack_prediction_indonesia.csv')

# %%
df.head()
# Out:
#    age  gender region income_level  hypertension  diabetes  cholesterol_level  \
# 0   60    Male  Rural       Middle             0         1                211
# 1   53  Female  Urban          Low             0         0                208
# 2   62  Female  Urban          Low             0         0                231
# 3   73    Male  Urban          Low             1         0                202
# 4   52    Male  Urban       Middle             1         0                232
#
#    obesity  waist_circumference  family_history  ... blood_pressure_diastolic  \
# 0        0                   83               0  ...                       62
# 1        0                  106               1  ...                       76
# 2        1                  112               1  ...                       74
# 3        0                   82               1  ...                       65
# 4        0                   89               0  ...                       75
#
#   fasting_blood_sugar cholesterol_hdl cholesterol_ldl triglycerides  \
# 0                 173              48             121           101
# 1                  70              58              83           138
# 2                 118              69             130           171
# 3                  98              52              85           146
# 4                 104              59             127           139
#
#   EKG_results  previous_heart_disease  medication_usage  \
# 0      Normal                       0                 0
# 1      Normal                       1                 0
# 2    Abnormal                       0                 1
# 3      Normal                       0                 1
# 4      Normal                       1                 0
#
#    participated_in_free_screening  heart_attack
# 0                               0             0
# 1                               1             0
# 2                               0             1
# 3                               1             0
# 4                               1             1
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158355 entries, 0 to 158354
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   age                             158355 non-null  int64
#  1   gender                          158355 non-null  object
#  2   region                          158355 non-null  object
#  3   income_level                    158355 non-null  object
#  4   hypertension                    158355 non-null  int64
#  5   diabetes                        158355 non-null  int64
#  6   cholesterol_level               158355 non-null  int64
#  7   obesity                         158355 non-null  int64
#  8   waist_circumference             158355 non-null  int64
#  9   family_history                  158355 non-null  int64
#  10  smoking_status                  158355 non-null  object
#  11  alcohol_consumption             63507 non-null   object
#  12  physical_activity               158355 non-null  object
#  13  dietary_habits                  158355 non-null  object
#  14  air_pollution_exposure          158355 non-null  object
#  15  stress_level                    158355 non-null  object
#  16  sleep_hours                     158355 non-null  float64
#  17  blood_pressure_systolic         158355 non-null  int64
#  18  blood_pressure_diastolic        158355 non-null  int64
#  19  fasting_blood_sugar             158355 non-null  int64
#  20  cholesterol_hdl                 158355 non-null  int64
#  21  cholesterol_ldl                 158355 non-null  int64
#  22  triglycerides                   158355 non-null  int64
#  23  EKG_results                     158355 non-null  object
#  24  previous_heart_disease          158355 non-null  int64
#  25  medication_usage                158355 non-null  int64
#  26  participated_in_free_screening  158355 non-null  int64
#  27  heart_attack                    158355 non-null  int64
# dtypes: float64(1), int64(17), object(10)
# memory usage: 33.8+ MB

# %%
df.columns
# Out:
# Index(['age', 'gender', 'region', 'income_level', 'hypertension', 'diabetes',
#        'cholesterol_level', 'obesity', 'waist_circumference', 'family_history',
#        'smoking_status', 'alcohol_consumption', 'physical_activity',
#        'dietary_habits', 'air_pollution_exposure', 'stress_level',
#        'sleep_hours', 'blood_pressure_systolic', 'blood_pressure_diastolic',
#        'fasting_blood_sugar', 'cholesterol_hdl', 'cholesterol_ldl',
#        'triglycerides', 'EKG_results', 'previous_heart_disease',
#        'medication_usage', 'participated_in_free_screening', 'heart_attack'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age                                 int64
# gender                             object
# region                             object
# income_level                       object
# hypertension                        int64
# diabetes                            int64
# cholesterol_level                   int64
# obesity                             int64
# waist_circumference                 int64
# family_history                      int64
# smoking_status                     object
# alcohol_consumption                object
# physical_activity                  object
# dietary_habits                     object
# air_pollution_exposure             object
# stress_level                       object
# sleep_hours                       float64
# blood_pressure_systolic             int64
# blood_pressure_diastolic            int64
# fasting_blood_sugar                 int64
# cholesterol_hdl                     int64
# cholesterol_ldl                     int64
# triglycerides                       int64
# EKG_results                        object
# previous_heart_disease              int64
# medication_usage                    int64
# participated_in_free_screening      int64
# heart_attack                        int64
# dtype: object

# %%
object_columns = df.select_dtypes(include=['object']).columns
object_columns
# Out:
# Index(['gender', 'region', 'income_level', 'smoking_status',
#        'alcohol_consumption', 'physical_activity', 'dietary_habits',
#        'air_pollution_exposure', 'stress_level', 'EKG_results'],
#       dtype='object')

# %%
df[object_columns]
# Out:
#         gender region income_level smoking_status alcohol_consumption  \
# 0         Male  Rural       Middle          Never                 NaN
# 1       Female  Urban          Low           Past                 NaN
# 2       Female  Urban          Low           Past            Moderate
# 3         Male  Urban          Low          Never            Moderate
# 4         Male  Urban       Middle        Current            Moderate
# ...        ...    ...          ...            ...                 ...
# 158350  Female  Rural       Middle          Never                 NaN
# 158351  Female  Urban          Low          Never                 NaN
# 158352    Male  Urban       Middle           Past            Moderate
# 158353    Male  Urban       Middle           Past                 NaN
# 158354    Male  Urban       Middle           Past                 NaN
#
#        physical_activity dietary_habits air_pollution_exposure stress_level  \
# 0                   High      Unhealthy               Moderate     Moderate
# 1               Moderate        Healthy                   High         High
# 2               Moderate        Healthy                    Low          Low
# 3               Moderate      Unhealthy                    Low         High
# 4               Moderate      Unhealthy                   High     Moderate
# ...                  ...            ...                    ...          ...
# 158350              High        Healthy               Moderate         High
# 158351          Moderate        Healthy                   High         High
# 158352               Low        Healthy                    Low     Moderate
# 158353               Low      Unhealthy                   High         High
# 158354          Moderate      Unhealthy               Moderate         High
#
#        EKG_results
# 0           Normal
# 1           Normal
# 2         Abnormal
# 3           Normal
# 4           Normal
# ...            ...
# 158350      Normal
# 158351      Normal
# 158352    Abnormal
# 158353      Normal
# 158354    Abnormal
#
# [158355 rows x 10 columns]

# %%
y = df['heart_attack']
X = df.drop(columns=['heart_attack'])

X = pd.get_dummies(X, drop_first=True)

# %%
X.sample(20)
# Out:
#         age  hypertension  diabetes  cholesterol_level  obesity  \
# 91277    37             0         0                187        0
# 40399    42             0         0                215        0
# 108846   46             0         0                177        1
# 20505    55             1         0                202        0
# 115789   60             0         0                197        0
# 43726    51             0         0                184        1
# 55195    26             1         1                197        0
# 125894   52             1         0                223        0
# 146941   48             1         0                158        0
# 20351    60             0         0                255        0
# 130663   62             0         0                145        0
# 108617   49             0         0                209        0
# 124174   54             0         0                167        0
# 41318    42             0         0                196        0
# 110628   59             0         1                204        0
# 155034   39             1         0                236        1
# 35269    70             0         1                246        1
# 59663    41             0         0                259        0
# 57815    61             1         0                235        1
# 133728   60             1         0                162        0
#
#         waist_circumference  family_history  sleep_hours  \
# 91277                    99               0     5.260902
# 40399                    95               1     5.320446
# 108846                   98               1     8.694623
# 20505                   108               0     4.593940
# 115789                   86               0     5.450820
# 43726                   100               0     6.473650
# 55195                   113               0     5.672934
# 125894                  108               0     9.000000
# 146941                   71               0     4.187342
# 20351                   100               0     7.846205
# 130663                   99               0     6.566771
# 108617                  114               1     6.450785
# 124174                  104               0     5.048432
# 41318                    91               0     5.846249
# 110628                  105               0     6.101099
# 155034                  114               0     6.587578
# 35269                    94               0     7.028843
# 59663                   109               1     8.707190
# 57815                    86               1     3.313909
# 133728                   84               1     7.658484
#
#         blood_pressure_systolic  blood_pressure_diastolic  ...  \
# 91277                       116                        73  ...
# 40399                       106                        65  ...
# 108846                      130                        57  ...
# 20505                       146                        92  ...
# 115789                       98                        88  ...
# 43726                       135                        83  ...
# 55195                       137                        77  ...
# 125894                      181                        93  ...
# 146941                      139                        77  ...
# 20351                        97                        75  ...
# 130663                      146                        75  ...
# 108617                      127                        78  ...
# 124174                      142                        71  ...
# 41318                       120                        80  ...
# 110628                      116                        83  ...
# 155034                      135                        83  ...
# 35269                       138                        74  ...
# 59663                       115                        72  ...
# 57815                       123                        73  ...
# 133728                      148                        90  ...
#
#         smoking_status_Past  alcohol_consumption_Moderate  \
# 91277                 False                          True
# 40399                 False                         False
# 108846                False                         False
# 20505                 False                         False
# 115789                False                         False
# 43726                 False                         False
# 55195                 False                         False
# 125894                False                         False
# 146941                False                          True
# 20351                 False                         False
# 130663                False                         False
# 108617                False                          True
# 124174                False                         False
# 41318                 False                          True
# 110628                False                          True
# 155034                 True                         False
# 35269                 False                         False
# 59663                 False                         False
# 57815                 False                         False
# 133728                False                          True
#
#         physical_activity_Low  physical_activity_Moderate  \
# 91277                   False                        True
# 40399                   False                        True
# 108846                  False                       False
# 20505                   False                        True
# 115789                  False                       False
# 43726                    True                       False
# 55195                    True                       False
# 125894                   True                       False
# 146941                  False                        True
# 20351                   False                        True
# 130663                  False                       False
# 108617                  False                        True
# 124174                  False                        True
# 41318                    True                       False
# 110628                  False                        True
# 155034                   True                       False
# 35269                   False                        True
# 59663                    True                       False
# 57815                    True                       False
# 133728                   True                       False
#
#         dietary_habits_Unhealthy  air_pollution_exposure_Low  \
# 91277                       True                       False
# 40399                       True                       False
# 108846                     False                       False
# 20505                       True                       False
# 115789                      True                       False
# 43726                       True                        True
# 55195                       True                       False
# 125894                     False                       False
# 146941                      True                       False
# 20351                       True                       False
# 130663                     False                        True
# 108617                      True                       False
# 124174                      True                       False
# 41318                      False                       False
# 110628                     False                       False
# 155034                      True                       False
# 35269                      False                        True
# 59663                       True                        True
# 57815                      False                       False
# 133728                      True                        True
#
#         air_pollution_exposure_Moderate  stress_level_Low  \
# 91277                              True             False
# 40399                             False              True
# 108846                             True             False
# 20505                             False             False
# 115789                             True             False
# 43726                             False              True
# 55195                              True              True
# 125894                             True             False
# 146941                            False             False
# 20351                              True              True
# 130663                            False             False
# 108617                             True             False
# 124174                             True             False
# 41318                              True              True
# 110628                             True              True
# 155034                            False             False
# 35269                             False             False
# 59663                             False             False
# 57815                              True             False
# 133728                            False             False
#
#         stress_level_Moderate  EKG_results_Normal
# 91277                    True                True
# 40399                   False                True
# 108846                   True                True
# 20505                    True               False
# 115789                   True                True
# 43726                   False               False
# 55195                   False                True
# 125894                  False                True
# 146941                   True                True
# 20351                   False               False
# 130663                  False                True
# 108617                   True                True
# 124174                   True                True
# 41318                   False               False
# 110628                  False                True
# 155034                   True                True
# 35269                    True                True
# 59663                    True                True
# 57815                    True                True
# 133728                  False                True
#
# [20 rows x 32 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=0)

model = LogisticRegression()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

accuracy_score(y_test, y_pred)
# Out:
# 0.7292475766474061

# %%
f1_score(y_test, y_pred)
# Out:
# 0.6304994182789676

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[15780,  3270],
#        [ 5305,  7316]])
